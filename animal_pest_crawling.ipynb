# %%
pip install wikipedia-api
# Out:
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests->wikipedia-api) (3.4)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.1-cp310-cp310-macosx_11_0_arm64.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.2/118.2 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests->wikipedia-api) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests->wikipedia-api) (2022.9.24)
# Installing collected packages: charset-normalizer, requests, wikipedia-api
# Successfully installed charset-normalizer-3.3.1 requests-2.31.0 wikipedia-api-0.6.0
#
# [notice] A new release of pip is available: 23.0 -> 23.3.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import wikipediaapi #사용할 api 호출
import pandas as pd

# %%
wiki = wikipediaapi.Wikipedia('Bigdata', 'en')
df = pd.read_csv('./CSV files/animal_pest_list.csv', encoding='utf-8')
for index, row in df.iterrows():
    page_py = wiki.page(row['영문'])
    if (pd.isna(row['영문']) or page_py.exists() != True):
        page_py = wiki.page(row['학명-수정'])
    print(index + 1)
    print("page: %s" %page_py)
    print("summary: %s" %page_py.text[0:10])
    df.at[index, '특성'] = page_py.text[0:1500]

df.to_csv('animal_pest_add_features.csv', index=False, encoding='utf-8-sig')
# Out:
# 1
# page: Acacia auriculiformis (id: 1732272, ns: 0)
# summary: Acacia aur
# 2
# page: Acacia confusa (id: ??, ns: 0)
# summary: Acacia con
# 3
# page: Acacia cyclops (id: ??, ns: 0)
# summary: Acacia cyc
# 4
# page: Acacia farnesiana (id: ??, ns: 0)
# summary: Vachellia
# 5
# page: Black wattle (id: 8113401, ns: 0)
# summary: Black watt
# 6
# page: Acacia paradoxa (id: ??, ns: 0)
# summary: Acacia par
# 7
# page: Acacia saligna (id: ??, ns: 0)
# summary: Acacia sal
# 8
# page: Acanthospermum australe (id: ??, ns: 0)
# summary: Acanthospe
# 9
# page: Acanthospermum hispidum (id: ??, ns: 0)
# summary: Acanthospe
# 10
# page: Acetosa sagittata (id: ??, ns: 0)
# summary: Rumex sagi
# 11
# page: Achatina achatina (id: ??, ns: 0)
# summary: Achatina a
# 12
# page: Achatina immaculata (id: ??, ns: 0)
# summary: Lissachati
# 13
# page: Russian bitterling (id: 11422887, ns: 0)
# summary: The Russia
# 14
# page: Acheilognathus tabira erythropterus (id: ??, ns: 0)
# summary: Acheilogna
# 15
# page: Acheilognathus tabira (id: ??, ns: 0)
# summary: Acheilogna
# 16
# page: Jungle myna (id: 640897, ns: 0)
# summary: The jungle
# 17
# page: Acridotheres ginginianus (id: ??, ns: 0)
# summary: The bank m
# 18
# page: Acridotheres javanicus (id: ??, ns: 0)
# summary: The Javan
# 19
# page: Common myna (id: 480171, ns: 0)
# summary: The common
# 20
# page: Aegilops geniculata (id: ??, ns: 0)
# summary: Aegilops g
# 21
# page: Aegilops tauschii (id: ??, ns: 0)
# summary: Aegilops t
# 22
# page: Aegilops triuncialis (id: ??, ns: 0)
# summary: Aegilops t
# 23
# page: Aethusa cynapium (id: ??, ns: 0)
# summary: Aethusa cy
# 24
# page: Mistflower (id: 21306045, ns: 0)
# summary: Mistflower
# 25
# page: Agropyron desertorum (id: ??, ns: 0)
# summary: Agropyron
# 26
# page: Bleak (id: 18791216, ns: 0)
# summary: Bleak may
# 27
# page: Danube bleak (id: 12183942, ns: 0)
# summary: The Danube
# 28
# page: Alhagi maurorum (id: ??, ns: 0)
# summary: Alhagi mau
# 29
# page: Alopochen aegyptiaca (id: ??, ns: 0)
# summary: The Egypti
# 30
# page: Alewife (id: 61938049, ns: 0)
# summary: Alewife ma
# 31
# page: American shad (id: 1261377, ns: 0)
# summary: The Americ
# 32
# page: Khakiweed (id: 16183571, ns: 0)
# summary: Khakiweed
# 33
# page: Amaranthus polygonoides (id: ??, ns: 0)
# summary: Amaranthus
# 34
# page: Black bullhead (id: 4788153, ns: 0)
# summary: The black
# 35
# page: Brown bullhead (id: 1174663, ns: 0)
# summary: The brown
# 36
# page: Giant ameiva (id: 9915615, ns: 0)
# summary: There are
# 37
# page: Amelanchier spicata (id: ??, ns: 0)
# summary: Amelanchie
# 38
# page: Amelichloa brachychaeta (id: ??, ns: 0)
# summary:
# 39
# page: Bowfin (id: 245146, ns: 0)
# summary: The bowfin
# 40
# page: Amphilophus citrinellus (id: 7345233, ns: 0)
# summary: Amphilophu
# 41
# page: Anaxyrus cognatus (id: ??, ns: 0)
# summary: The Great
# 42
# page: Anaxyrus punctatus (id: ??, ns: 0)
# summary: The red-sp
# 43
# page: Anaxyrus quercicus (id: ??, ns: 0)
# summary: The oak to
# 44
# page: Andropogon gayanus (id: 33982892, ns: 0)
# summary: Andropogon
# 45
# page: Anolis aeneus (id: ??, ns: 0)
# summary: The Grenad
# 46
# page: Anolis allogus (id: ??, ns: 0)
# summary: Anolis all
# 47
# page: Anolis alutaceus (id: 67911971, ns: 0)
# summary: Anolis alu
# 48
# page: Hispaniolan green anole (id: 36512559, ns: 0)
# summary: There are
# 49
# page: Anolis cybotes (id: 21100957, ns: 0)
# summary: Anolis cyb
# 50
# page: Anolis garmani (id: 21084946, ns: 0)
# summary: Anolis gar
# 51
# page: Anolis homolechis (id: ??, ns: 0)
# summary: Anolis hom
# 52
# page: Anolis lineatus (id: ??, ns: 0)
# summary: The Curaca
# 53
# page: Anolis richardii (id: 26591070, ns: 0)
# summary: Anolis ric
# 54
# page: Anolis sagrei (id: ??, ns: 0)
# summary: The brown
# 55
# page: Anolis wattsii (id: 26540729, ns: 0)
# summary: Anolis wat
# 56
# page: Anredera cordifolia (id: ??, ns: 0)
# summary: Anredera c
# 57
# page: Apera spica-venti (id: ??, ns: 0)
# summary: Apera spic
# 58
# page: Aplonis panayensis (id: ??, ns: 0)
# summary: The Asian
# 59
# page: Arctotheca calendula (id: 3451860, ns: 0)
# summary: Arctotheca
# 60
# page: Ardisia elliptica (id: ??, ns: 0)
# summary: Ardisia el
# 61
# page: Spanish slug (id: 4230388, ns: 0)
# summary: The Spanis
# 62
# page: Asparagus aethiopicus (id: ??, ns: 0)
# summary: Asparagus
# 63
# page: Asparagus asparagoides (id: 7925101, ns: 0)
# summary: Asparagus
# 64
# page: Asparagus scandens (id: ??, ns: 0)
# summary: Asparagus
# 65
# page: Asp (id: 427891, ns: 0)
# summary: Asp may re
# 66
# page: Atelerix albiventris (id: ??, ns: 0)
# summary: The four-t
# 67
# page: Alligator gar (id: 1742933, ns: 0)
# summary: The alliga
# 68
# page: Sydney funnel-web spider (id: 2728568, ns: 0)
# summary: The Sydney
# 69
# page: Atriplex semibaccata (id: ??, ns: 0)
# summary: Atriplex s
# 70
# page: Australoheros facetus (id: ??, ns: 0)
# summary: Australohe
# 71
# page: Avena barbata (id: ??, ns: 0)
# summary: Avena barb
# 72
# page: Axonopus compressus (id: ??, ns: 0)
# summary: Axonopus c
# 73
# page: Axonopus fissifolius (id: ??, ns: 0)
# summary: Axonopus f
# 74
# page: Babka gymnotrachelus (id: ??, ns: 0)
# summary: The racer
# 75
# page: Badumna insignis (id: ??, ns: 0)
# summary: The black
# 76
# page: Bambusa bambos (id: ??, ns: 0)
# summary: Bambusa ba
# 77
# page: Bambusa vulgaris (id: ??, ns: 0)
# summary: Bambusa vu
# 78
# page: Bandicota indica (id: ??, ns: 0)
# summary: The greate
# 79
# page: Barbel (id: 5735056, ns: 0)
# summary: Barbel may
# 80
# page: Barbus plebejus (id: ??, ns: 0)
# summary: The Italia
# 81
# page: Bassia hyssopifolia (id: ??, ns: 0)
# summary: Bassia hys
# 82
# page: Berteroa incana (id: 18440766, ns: 0)
# summary: Berteroa i
# 83
# page: Biwia zezera (id: ??, ns: 0)
# summary: Biwia zeze
# 84
# page: Boiga cyanea (id: 3595121, ns: 0)
# summary: Boiga cyan
# 85
# page: Boiga cynodon (id: ??, ns: 0)
# summary: Boiga cyno
# 86
# page: Brown tree snake (id: 1627313, ns: 0)
# summary: The brown
# 87
# page: Boiga nigriceps (id: ??, ns: 0)
# summary: Boiga nigr
# 88
# page: Bombina bombina (id: ??, ns: 0)
# summary: The Europe
# 89
# page: Bombina variegata (id: ??, ns: 0)
# summary: The yellow
# 90
# page: Brachiaria mutica (id: 47197053, ns: 0)
# summary: Brachiaria
# 91
# page: Bromus arvensis (id: ??, ns: 0)
# summary: Bromus arv
# 92
# page: Bromus briziformis (id: ??, ns: 0)
# summary: Bromus bri
# 93
# page: Bromus rubens (id: ??, ns: 0)
# summary: Bromus mad
# 94
# page: Smokebush (id: 1820112, ns: 0)
# summary: Smokebush
# 95
# page: Japanese common toad (id: 12358874, ns: 0)
# summary: The Japane
# 96
# page: Japanese common toad (id: 12358874, ns: 0)
# summary: The Japane
# 97
# page: Texas toad (id: 4974030, ns: 0)
# summary: The Texas
# 98
# page: Bufo typhonius (id: ??, ns: 0)
# summary:
# 99
# page: Bunias orientalis (id: ??, ns: 0)
# summary: Bunias ori
# 100
# page: Cakile maritima (id: ??, ns: 0)
# summary: Cakile mar
# 101
# page: Callosciurus erythraeus (id: ??, ns: 0)
# summary: Pallas's s
